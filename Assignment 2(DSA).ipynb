# %% [markdown]
# Write Python functions for basic tasks such as a calculator, discount calculator, grade
# evaluator, and even/odd checker; demonstrate array operations like swapping, splitting,
# inserting, and deleting

# %% [markdown]
# Part A

# %%
a = int(input("enter your first number:"))
b = int(input("enter your second number:"))

#addition
print("your sum of the two number is", a+b)

# subtraction
print("your difference of the two number is", a-b)

#multiplication
print("your product of two number is", a*b)

#division
print("your quotient of two number is", a/b)

#exponent: raises one number to the power of the other 
print("your exponent value of two number is", a**b)
# Out:
# enter your first number: 5
# enter your second number: 5
# your sum of the two number is 10
# your difference of the two number is 0
# your product of two number is 25
# your quotient of two number is 1.0
# your exponent value of two number is 3125

# %%
#Discount Calulator
def discount(amount):
    if amount>=5000:
        disc=amount*0.20
    elif amount>=3000:
        disc=amount*0.10
    else:
        disc=0
    print("Discount:",disc)
    print("Final Amount",amount-disc)
amount=float(input("enter purchase amount:"))
discount(amount)
# Out:
# enter purchase amount: 6000
# Discount: 1200.0
# Final Amount 4800.0

# %%
#grade evaluator
marks = int(input("enter your marks:"))
if marks>=90:
    print("A+")
elif marks>=85:
    print("A")
elif marks>=70:
    print("B+")
elif marks>=60:
    print("B")
else:
    print("C")
# Out:
# enter your marks: 68
# B

# %%
num= int(input("enter your number:"))
if num%2==0:
    print("Its an even number")
else:
    print("Its a odd number")
# Out:
# enter your number: 8
# Its an even number

# %% [markdown]
# ARRAY OPERATIONS

# %%
import numpy as np

# %%
#swapping
arr = np.array([3,4,5,7,8,9])
i = int(input("enter your first index:"))
j= int(input("enter your second index:"))

arr[i],arr[j] =arr[j],arr[i]
print("array after swapping:",arr)
# Out:
# enter your first index: 3
# enter your second index: 0
# array after swapping: [7 4 5 3 8 9]

# %%
#inserting

#.insert
arr1 = [10,20,30,60]
arr1.insert(3,80)
print("Array after insertion:",arr1)
# Out:
# Array after insertion: [10, 20, 30, 80, 60]

# %%
# Deletion
arr = [60,36,89,20,70]
arr.remove(89)
print("array after deletion:",arr)
# Out:
# array after deletion: [60, 36, 20, 70]

# %% [markdown]
# Part B

# %% [markdown]
# Solving a quadratic equation

# %%
import math

def quadratic(a, b, c):
    d = b*b - 4*a*c
    
    if d > 0:
        r1 = (-b + math.sqrt(d)) / (2*a)
        r2 = (-b - math.sqrt(d)) / (2*a)
        return r1, r2
    
    elif d == 0:
        r = -b / (2*a)
        return r
    
    else:
        real = -b / (2*a)
        imaginary = math.sqrt(-d) / (2*a)
        return complex(real, imaginary), complex(real, -imaginary)


a = float(input("Enter value of a: "))
b = float(input("Enter value of b: "))
c = float(input("Enter value of c: "))

if a == 0:
    print("Not a quadratic equation")
else:
    result = quadratic(a, b, c)
    print("Result:", result)
# Out:
# Enter value of a:  0.4
# Enter value of b:  7.4
# Enter value of c:  2
# Result: (-0.27433846449187893, -18.22566153550812)

# %% [markdown]
# Bubble Sort

# %%
def BBS(array):
  n = len(array)
  for i in range(n-1):
    for j in range (n-1-i):
      if array[j] > array[j+1]:
        array[j], array[j+1] = array[j+1],array[j]
  return array

data= [10,9,8,7,6]
print(BBS(data))
# Out:
# [6, 7, 8, 9, 10]

# %% [markdown]
# Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n):
        min_index = i
        for j in range(i+1, n):
            if arr[j] < arr[min_index]:
              min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
        
    return arr
arr = [67,87,44,33,24]
print(selection_sort(arr))
# Out:
# [11, 12, 22, 25, 64]

# %% [markdown]
# Insertion Sort

# %%
arr = [15,14,13,12,11]
for i in range(1, len(arr)):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j -= 1
    arr[j + 1] = key
print(arr)
# Out:
# [11, 12, 13, 14, 15]

# %% [markdown]
# Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[-1]   
    left = []
    right = []
    for i in range(len(arr) - 1):
        if arr[i] < pivot:
            left.append(arr[i])
        else:
            right.append(arr[i])
    return quick_sort(left) + [pivot] + quick_sort(right)
# Example
arr = [4,7,8,6,3,2]
sorted_arr = quick_sort(arr)
print("Sorted array:", sorted_arr)
# Out:
# Sorted array: [2, 3, 4, 6, 7, 8]
